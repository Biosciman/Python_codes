# %%
# 导包
import pandas as pd
import numpy as np
import re

# %%
# 导入爬取得到的数据
df = pd.read_csv("月饼.csv", engine='python', encoding='utf-8-sig', header=None)
df.columns = ["商品名", "价格", "付款人数", "店铺", "发货地址"]
df.head(10)
# Out:
#                                  商品名     价格     付款人数            店铺   发货地址
# 0  【礼券】GODIVA歌帝梵中秋限量版礼盒组合装巧克力月饼形糕点送礼  262.0    41人付款  godiva歌帝梵旗舰店     上海
# 1     知味观清风揽月中秋广式月饼礼盒装流心奶黄高档团购批发送礼礼品  158.0   142人付款      知味观官方旗舰店  浙江 杭州
# 2     中秋月饼提篮礼盒装中秋节礼品冰皮五仁散装多口味大月饼送礼团购   99.0   968人付款        or7028  福建 泉州
# 3  amalee艾玛琳燕窝月饼礼盒装散装流心奶黄多口味广式中秋送礼高档  298.0  1168人付款      年轮堂食品专营店  广东 东莞
# 4     中秋月饼礼盒装广式五仁椰蓉蛋黄豆沙酥月饼散装多口味送礼品老式   29.9   485人付款        欧贝拉旗舰店  福建 厦门
# 5  amalee艾玛琳燕窝月饼礼盒装散装广式多口味流心奶黄中秋送礼高档  298.0  1213人付款       雨田食品专营店  广东 东莞
# 6     恒宝月饼礼盒装散装广式多口味中秋节双黄蛋黄莲蓉香港送礼大高档  168.0  1281人付款      年轮堂食品专营店  广东 东莞
# 7     猫山王榴莲冰皮月饼礼盒装 中秋节高端流心网红水果月饼送人礼品  288.0   453人付款      盛园祥食品旗舰店  江苏 苏州
# 8      三山五园联名款颐和园中秋流心奶黄月饼礼盒装台式酥皮月饼送礼  188.0   359人付款      多一步食品专营店  福建 厦门
# 9     高档中秋节手工台式酥皮流心奶黄散装多口味月饼送礼品团购礼盒装  198.0    75人付款     六八创享食品专营店  福建 厦门

# %%
# 去除重复值
print(df.shape)
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (4404, 5)
# (1727, 5)

# %%
# 处理购买人数为空的记录
df['付款人数'] = df['付款人数'].replace(np.nan,'0人付款')

# %%
# 提取数值
df['num'] = [re.findall(r'(\d+\.{0,1}\d*)', i)[0] for i in df['付款人数']]  # 提取数值
df['num'] = df['num'].astype('float')  # 转化数值型
# 提取单位（万）
df['unit'] = [''.join(re.findall(r'(万)', i)) for i in df['付款人数']]  # 提取单位（万）
df['unit'] = df['unit'].apply(lambda x:10000 if x=='万' else 1)
# 计算销量
df['销量'] = df['num'] * df['unit']

# %%
# 删除无发货地址的商品，并提取省份
df = df[df['发货地址'].notna()]
df['省份'] = df['发货地址'].str.split(' ').apply(lambda x:x[0])

# %%
# 删除多余的列
df.drop(['付款人数', '发货地址', 'num', 'unit'], axis=1, inplace=True)

# 重置索引
df = df.reset_index(drop=True)
df.to_csv('清洗完成数据.csv',encoding="gbk")

# %%
df.head(10)
# Out:
#                                  商品名     价格            店铺      销量  省份
# 0  【礼券】GODIVA歌帝梵中秋限量版礼盒组合装巧克力月饼形糕点送礼  262.0  godiva歌帝梵旗舰店    41.0  上海
# 1     知味观清风揽月中秋广式月饼礼盒装流心奶黄高档团购批发送礼礼品  158.0      知味观官方旗舰店   142.0  浙江
# 2     中秋月饼提篮礼盒装中秋节礼品冰皮五仁散装多口味大月饼送礼团购   99.0        or7028   968.0  福建
# 3  amalee艾玛琳燕窝月饼礼盒装散装流心奶黄多口味广式中秋送礼高档  298.0      年轮堂食品专营店  1168.0  广东
# 4     中秋月饼礼盒装广式五仁椰蓉蛋黄豆沙酥月饼散装多口味送礼品老式   29.9        欧贝拉旗舰店   485.0  福建
# 5  amalee艾玛琳燕窝月饼礼盒装散装广式多口味流心奶黄中秋送礼高档  298.0       雨田食品专营店  1213.0  广东
# 6     恒宝月饼礼盒装散装广式多口味中秋节双黄蛋黄莲蓉香港送礼大高档  168.0      年轮堂食品专营店  1281.0  广东
# 7     猫山王榴莲冰皮月饼礼盒装 中秋节高端流心网红水果月饼送人礼品  288.0      盛园祥食品旗舰店   453.0  江苏
# 8      三山五园联名款颐和园中秋流心奶黄月饼礼盒装台式酥皮月饼送礼  188.0      多一步食品专营店   359.0  福建
# 9     高档中秋节手工台式酥皮流心奶黄散装多口味月饼送礼品团购礼盒装  198.0     六八创享食品专营店    75.0  福建

# %%
df1 = df.sort_values(by="价格", axis=0, ascending=False)
df1.iloc[:5,:]
# Out:
#                                    商品名      价格             店铺     销量  省份
# 1397  上海北京宝格丽酒店2020“盈月朝花”中秋月饼礼盒顺丰冷运发全国  1398.0  shanxianms001   15.0  上海
# 1432    五芳斋望月饼礼盒组合装多口味流心奶黄糯月饼广式中秋节送礼团购  1339.0       五芳斋官方旗舰店    4.0  浙江
# 709   哈根达斯月饼券金尊898型冰淇淋月饼礼盒北京 上海通用全国提货券   718.8          snpee  109.0  北京
# 837    2020官方哈根达斯月饼券898型金尊冰淇淋月饼提货券全国通用   718.4         淘淘的小店儿  208.0  北京
# 1694  哈根达斯月饼券票中秋高端礼盒提货券冰淇淋月饼898型金尊 全国用   673.5       jurry999   32.0  上海

# %% [markdown]
# # 数据可视化展示

# %% [markdown]
# ## 商品销量排名top10 - 柱形图

# %%
# 导入包
from pyecharts.charts import Bar
from pyecharts import options as opts 

# 计算top10店铺
shop_top10 = df.groupby('商品名')['销量'].sum().sort_values(ascending=False).head(10)

# 绘制柱形图
bar0 = Bar(init_opts=opts.InitOpts(width='750px', height='350px')) 
bar0.add_xaxis(shop_top10.index.tolist())
bar0.add_yaxis('sales_num', shop_top10.values.tolist()) 
bar0.set_global_opts(title_opts=opts.TitleOpts(title='月饼商品销量Top10'),
                     xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30))) 
#bar0.render("月饼商品销量Top10.html")
bar0.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1a14268c5998417bb4c4cd0ba1d4cdb4" style="width:750px; height:350px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1a14268c5998417bb4c4cd0ba1d4cdb4 = echarts.init(
#                     document.getElementById('1a14268c5998417bb4c4cd0ba1d4cdb4'), 'white', {renderer: 'canvas'});
#                 var option_1a14268c5998417bb4c4cd0ba1d4cdb4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "sales_num",
#             "data": [
#                 800000.0,
#                 650000.0,
#                 450000.0,
#                 300000.0,
#                 300000.0,
#                 200000.0,
#                 150000.0,
#                 100000.0,
#                 100000.0,
#                 100000.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sales_num"
#             ],
#             "selected": {
#                 "sales_num": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7a3b\u9999\u6751\u6708\u997c\u793c\u76d2\u88c5\u53cc\u86cb\u9ec4\u83b2\u84c9\u8001\u5f0f\u5e7f\u5f0f\u4e94\u4ec1\u8c46\u6c99\u591a\u53e3\u5473\u6563\u88c5\u4e2d\u79cb\u9001\u793c",
#                 "\u534e\u7f8e\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u53cc\u86cb\u9ec4\u83b2\u84c9\u6563\u88c5\u591a\u53e3\u5473\u4e2d\u79cb\u9001\u793c\u56e2\u8d2d\u5927\u793c\u5305810g",
#                 "\u4e94\u82b3\u658b\u6708\u997c\u793c\u76d2\u88c5\u86cb\u9ec4\u83b2\u84c9\u8c46\u6c99\u6708\u997c\u591a\u53e3\u5473\u6563\u88c5\u56e2\u8d2d\u9001\u793c\u5e7f\u5f0f\u4e2d\u79cb\u8282",
#                 "\u9c9c\u54c1\u5c4b\u6708\u997c\u793c\u76d2\u88c51020g\u5e7f\u5f0f\u4e94\u4ec1\u6d41\u5fc3\u86cb\u9ec4\u83b2\u84c9\u6563\u88c5\u591a\u53e3\u5473\u4e2d\u79cb\u9001\u793c",
#                 "\u7a3b\u9999\u6751\u6708\u997c\u793c\u76d2\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u4e94\u4ec1\u8c46\u6c99\u591a\u53e3\u5473\u6563\u88c5\u4e2d\u79cb\u8282\u56e2\u8d2d\u9001\u793c\u54c1",
#                 "\u8343\u76db\u6708\u997c\u793c\u76d2\u88c5\u86cb\u9ec4\u83b2\u84c9\u6708\u997c\u51b0\u76ae\u5e7f\u5f0f\u6708\u997c\u6563\u88c5\u591a\u53e3\u5473\u56e2\u8d2d\u4e2d\u79cb\u9001\u793c",
#                 "\u7a3b\u9999\u6751\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u4e2d\u79cb\u8282\u86cb\u9ec4\u83b2\u84c9\u8c46\u6c99\u4e94\u4ec1\u6563\u88c5\u591a\u53e3\u5473\u56e2\u8d2d\u9001\u793c",
#                 "\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u96f6\u98df\u7cd5\u70b9\u4e94\u4ec1\u4e2d\u79cb\u8282\u5458\u5de5\u6279\u53d1\u56e2\u8d2d\u9001\u793c\u793c\u54c1",
#                 "\u77e5\u5473\u89c2\u4e2d\u79cb\u6708\u997c\u793c\u76d2\u88c5\u6d41\u5fc3\u5976\u9ec4\u82cf\u5f0f\u6728\u7cd6\u9187\u9985\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u56e2\u8d2d\u9001\u793c",
#                 "\u8343\u76db\u71d5\u7a9d\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u8c46\u6c99\u51b0\u76ae\u6708\u997c\u6563\u88c5\u591a\u53e3\u5473\u4e2d\u79cb\u9001\u793c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6708\u997c\u5546\u54c1\u9500\u91cfTop10",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1a14268c5998417bb4c4cd0ba1d4cdb4.setOption(option_1a14268c5998417bb4c4cd0ba1d4cdb4);
#         });
#     </script>

# %% [markdown]
# ## 店铺销量排名top10 - 柱形图

# %%
# 导入包
from pyecharts.charts import Bar
from pyecharts import options as opts 

# 计算top10店铺
shop_top10 = df.groupby('店铺')['销量'].sum().sort_values(ascending=False).head(10)

# 绘制柱形图
bar1 = Bar(init_opts=opts.InitOpts(width='750px', height='350px')) 
bar1.add_xaxis(shop_top10.index.tolist())
bar1.add_yaxis('sales_num', shop_top10.values.tolist()) 
bar1.set_global_opts(title_opts=opts.TitleOpts(title='月饼店铺销量Top10'),
                     xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30))) 
#bar1.render("月饼店铺销量Top10.html")
bar1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b33ca6a07d1247e8974610caf75739b0" style="width:750px; height:350px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b33ca6a07d1247e8974610caf75739b0 = echarts.init(
#                     document.getElementById('b33ca6a07d1247e8974610caf75739b0'), 'white', {renderer: 'canvas'});
#                 var option_b33ca6a07d1247e8974610caf75739b0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "sales_num",
#             "data": [
#                 914556.0,
#                 668112.0,
#                 487861.0,
#                 309570.0,
#                 306026.0,
#                 301724.0,
#                 185000.0,
#                 177142.0,
#                 101385.0,
#                 100000.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sales_num"
#             ],
#             "selected": {
#                 "sales_num": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7a3b\u9999\u6751\u98df\u54c1\u65d7\u8230\u5e97",
#                 "\u534e\u7f8e\u98df\u54c1\u65d7\u8230\u5e97",
#                 "\u4e94\u82b3\u658b\u5b98\u65b9\u65d7\u8230\u5e97",
#                 "\u7a3b\u9999\u6751\u661f\u7693\u4e13\u5356\u5e97",
#                 "\u8343\u76db\u65d7\u8230\u5e97",
#                 "\u81fb\u5473\u98df\u54c1\u65d7\u8230\u5e97",
#                 "\u7a3b\u9999\u6751\u535a\u96c5\u4e13\u5356\u5e97",
#                 "\u77e5\u5473\u89c2\u5b98\u65b9\u65d7\u8230\u5e97",
#                 "\u8343\u76db\u8bfa\u838e\u6735\u4e13\u5356\u5e97",
#                 "\u9753\u5c0f\u767d\u65d7\u8230\u5e97"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6708\u997c\u5e97\u94fa\u9500\u91cfTop10",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b33ca6a07d1247e8974610caf75739b0.setOption(option_b33ca6a07d1247e8974610caf75739b0);
#         });
#     </script>

# %% [markdown]
# ## 全国省份销量地区分布-地图

# %%
from pyecharts.charts import Map 

# 计算销量
province_num = df.groupby('省份')['销量'].sum().sort_values(ascending=False) 

# 绘制地图
map1 = Map(init_opts=opts.InitOpts(width='750px', height='350px'))
map1.add("", [list(z) for z in zip(province_num.index.tolist(), province_num.values.tolist())],
         maptype='china'
        ) 
map1.set_global_opts(title_opts=opts.TitleOpts(title='各省份月饼销量分布'),
                     visualmap_opts=opts.VisualMapOpts(max_=300000)
                    )
#map1.render("各省份月饼销量分布.html")
map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="a31786d099704a52964602477ffdab3b" style="width:750px; height:350px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_a31786d099704a52964602477ffdab3b = echarts.init(
#                     document.getElementById('a31786d099704a52964602477ffdab3b'), 'white', {renderer: 'canvas'});
#                 var option_a31786d099704a52964602477ffdab3b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1555660.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1293236.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1288379.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 367807.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 287115.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 285091.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 179914.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 144604.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 94871.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 69252.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 68308.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 57961.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 36070.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 32637.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 19861.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 19492.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 18166.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 13204.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 11858.0
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 5460.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 5210.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 4484.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 4266.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 1514.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1274.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 720.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 58.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u7701\u4efd\u6708\u997c\u9500\u91cf\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 300000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_a31786d099704a52964602477ffdab3b.setOption(option_a31786d099704a52964602477ffdab3b);
#         });
#     </script>

# %% [markdown]
# ## 不同价格区间的销量占比

# %%
from pyecharts.charts import Pie

def price_range(x): #按照淘宝推荐划分价格区间
    if x <= 22:
        return '22元以下'
    elif x <= 115:
        return '22-115元'
    elif x <= 633:
        return '115-633元'
    else:
        return '633元以上'

df['price_range'] = df['价格'].apply(lambda x: price_range(x)) 
price_cut_num = df.groupby('price_range')['销量'].sum() 
data_pair = [list(z) for z in zip(price_cut_num.index, price_cut_num.values)]
print(data_pair)


# 饼图
pie1 = Pie(init_opts=opts.InitOpts(width='750px', height='350px'))
# 内置富文本
pie1.add( 
        series_name="销量",
        radius=["35%", "55%"],
        data_pair=data_pair,
        label_opts=opts.LabelOpts(formatter='{{b}—占比{d}%}'),
)

pie1.set_global_opts(legend_opts=opts.LegendOpts(pos_left="left", pos_top='30%', orient="vertical"), 
                     title_opts=opts.TitleOpts(title='不同价格区间的月饼销量占比'))

#pie1.render("不同价格区间的月饼销量占比.html")
pie1.render_notebook()
# Out:
# [['115-633元', 386729.0], ['22-115元', 4937689.0], ['22元以下', 541408.0], ['633元以上', 646.0]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c64979b5b9dd42a99b128a1f88a476aa" style="width:750px; height:350px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c64979b5b9dd42a99b128a1f88a476aa = echarts.init(
#                     document.getElementById('c64979b5b9dd42a99b128a1f88a476aa'), 'white', {renderer: 'canvas'});
#                 var option_c64979b5b9dd42a99b128a1f88a476aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9500\u91cf",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "115-633\u5143",
#                     "value": 386729.0
#                 },
#                 {
#                     "name": "22-115\u5143",
#                     "value": 4937689.0
#                 },
#                 {
#                     "name": "22\u5143\u4ee5\u4e0b",
#                     "value": 541408.0
#                 },
#                 {
#                     "name": "633\u5143\u4ee5\u4e0a",
#                     "value": 646.0
#                 }
#             ],
#             "radius": [
#                 "35%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{{b}\u2014\u5360\u6bd4{d}%}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "115-633\u5143",
#                 "22-115\u5143",
#                 "22\u5143\u4ee5\u4e0b",
#                 "633\u5143\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "left",
#             "top": "30%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e0d\u540c\u4ef7\u683c\u533a\u95f4\u7684\u6708\u997c\u9500\u91cf\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c64979b5b9dd42a99b128a1f88a476aa.setOption(option_c64979b5b9dd42a99b128a1f88a476aa);
#         });
#     </script>

# %% [markdown]
# ## 商品标题文本分析 - 词云图

# %%
import jieba
import jieba.analyse

txt = df['商品名'].str.cat(sep='。')

# 添加关键词
jieba.add_word('粽子', 999, '五芳斋')

# 读入停用词表
stop_words = []
with open('stop_words.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        stop_words.append(line.strip())

# 添加停用词
stop_words.extend(['logo', '10', '100', '200g', '100g', '140g', '130g', '月饼', '礼盒装'])  

# 评论字段分词处理
word_num = jieba.analyse.extract_tags(txt,
                                      topK=100,
                                      withWeight=True,
                                      allowPOS=())

# 去停用词
word_num_selected = []

for i in word_num:
    if i[0] not in stop_words:
        word_num_selected.append(i)

key_words = pd.DataFrame(word_num_selected, columns=['words','num'])

# %%
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

# 词云图
word1 = WordCloud(init_opts=opts.InitOpts(width='750px', height='350px'))
word1.add("", [*zip(key_words.words, key_words.num)],
          word_size_range=[20, 200],
          shape=SymbolType.DIAMOND)
word1.set_global_opts(title_opts=opts.TitleOpts('月饼商品名称词云图'))
#word1.render("月饼商品名称词云图.html")
word1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="0c3ececd78684bd0b1ac50453fa5fcc9" style="width:750px; height:350px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_0c3ececd78684bd0b1ac50453fa5fcc9 = echarts.init(
#                     document.getElementById('0c3ececd78684bd0b1ac50453fa5fcc9'), 'white', {renderer: 'canvas'});
#                 var option_0c3ececd78684bd0b1ac50453fa5fcc9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 200
#             ],
#             "data": [
#                 {
#                     "name": "\u5e7f\u5f0f",
#                     "value": 0.3788998083004474,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,86,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9001\u793c",
#                     "value": 0.34937758324217244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,119,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u86cb\u9ec4",
#                     "value": 0.3364420434057728,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,9,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u83b2\u84c9",
#                     "value": 0.32779356496316286,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,138,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u793c\u76d2",
#                     "value": 0.32763708634694405,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,113,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u79cb",
#                     "value": 0.29728429638739196,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,19,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u8d2d",
#                     "value": 0.25253376645725345,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,134,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53e3\u5473",
#                     "value": 0.2373475975493727,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,5,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u79cb\u8282",
#                     "value": 0.17805585932158235,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,12,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u79cb\u6708\u997c",
#                     "value": 0.16109778619631723,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,126,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6563\u88c5",
#                     "value": 0.1547644051386903,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,122,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e94\u4ec1",
#                     "value": 0.1514473230799708,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,25,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u793c\u54c1",
#                     "value": 0.12975278026424036,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,86,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d41\u5fc3\u5976",
#                     "value": 0.11541524621336065,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,136,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8c46\u6c99",
#                     "value": 0.11469580938960158,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,11,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u63d0\u8d27",
#                     "value": 0.08917580090755392,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,17,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a3b\u9999\u6751",
#                     "value": 0.0860218570422012,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,70,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9165\u76ae",
#                     "value": 0.08139205161747669,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,129,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cd5\u70b9",
#                     "value": 0.07963139934415937,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,75,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u9ec4",
#                     "value": 0.06933955658555147,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,99,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8001\u5f0f",
#                     "value": 0.0677682545209061,
#                     "textStyle": {

# %%
from pyecharts.charts import Page

page = Page(layout=Page.DraggablePageLayout)
page.add(
    bar0,
    bar1,
    pie1,
    word1,
    map1
)
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e5bcdacf90af4587bd2e07a480c25bde" style="width:750px; height:350px;"></div>
#         <div id="3be233316eb34ca097fbc9fd4f9d6f3a" style="width:750px; height:350px;"></div>
#         <div id="641affa65f72426ba5fa38ad4bad7a1e" style="width:750px; height:350px;"></div>
#         <div id="77f9b601f71344f2b6d085a7d1105b5f" style="width:750px; height:350px;"></div>
#         <div id="2b90bca208c24537a1d5b3a57d1ef4d8" style="width:750px; height:350px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'china'], function(echarts) {
#                 var chart_e5bcdacf90af4587bd2e07a480c25bde = echarts.init(
#                     document.getElementById('e5bcdacf90af4587bd2e07a480c25bde'), 'white', {renderer: 'canvas'});
#                 var option_e5bcdacf90af4587bd2e07a480c25bde = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "sales_num",
#             "data": [
#                 800000.0,
#                 650000.0,
#                 450000.0,
#                 300000.0,
#                 300000.0,
#                 200000.0,
#                 150000.0,
#                 100000.0,
#                 100000.0,
#                 100000.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "sales_num"
#             ],
#             "selected": {
#                 "sales_num": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -15,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7a3b\u9999\u6751\u6708\u997c\u793c\u76d2\u88c5\u53cc\u86cb\u9ec4\u83b2\u84c9\u8001\u5f0f\u5e7f\u5f0f\u4e94\u4ec1\u8c46\u6c99\u591a\u53e3\u5473\u6563\u88c5\u4e2d\u79cb\u9001\u793c",
#                 "\u534e\u7f8e\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u53cc\u86cb\u9ec4\u83b2\u84c9\u6563\u88c5\u591a\u53e3\u5473\u4e2d\u79cb\u9001\u793c\u56e2\u8d2d\u5927\u793c\u5305810g",
#                 "\u4e94\u82b3\u658b\u6708\u997c\u793c\u76d2\u88c5\u86cb\u9ec4\u83b2\u84c9\u8c46\u6c99\u6708\u997c\u591a\u53e3\u5473\u6563\u88c5\u56e2\u8d2d\u9001\u793c\u5e7f\u5f0f\u4e2d\u79cb\u8282",
#                 "\u9c9c\u54c1\u5c4b\u6708\u997c\u793c\u76d2\u88c51020g\u5e7f\u5f0f\u4e94\u4ec1\u6d41\u5fc3\u86cb\u9ec4\u83b2\u84c9\u6563\u88c5\u591a\u53e3\u5473\u4e2d\u79cb\u9001\u793c",
#                 "\u7a3b\u9999\u6751\u6708\u997c\u793c\u76d2\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u4e94\u4ec1\u8c46\u6c99\u591a\u53e3\u5473\u6563\u88c5\u4e2d\u79cb\u8282\u56e2\u8d2d\u9001\u793c\u54c1",
#                 "\u8343\u76db\u6708\u997c\u793c\u76d2\u88c5\u86cb\u9ec4\u83b2\u84c9\u6708\u997c\u51b0\u76ae\u5e7f\u5f0f\u6708\u997c\u6563\u88c5\u591a\u53e3\u5473\u56e2\u8d2d\u4e2d\u79cb\u9001\u793c",
#                 "\u7a3b\u9999\u6751\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u4e2d\u79cb\u8282\u86cb\u9ec4\u83b2\u84c9\u8c46\u6c99\u4e94\u4ec1\u6563\u88c5\u591a\u53e3\u5473\u56e2\u8d2d\u9001\u793c",
#                 "\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u96f6\u98df\u7cd5\u70b9\u4e94\u4ec1\u4e2d\u79cb\u8282\u5458\u5de5\u6279\u53d1\u56e2\u8d2d\u9001\u793c\u793c\u54c1",
#                 "\u77e5\u5473\u89c2\u4e2d\u79cb\u6708\u997c\u793c\u76d2\u88c5\u6d41\u5fc3\u5976\u9ec4\u82cf\u5f0f\u6728\u7cd6\u9187\u9985\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u56e2\u8d2d\u9001\u793c",
#                 "\u8343\u76db\u71d5\u7a9d\u6708\u997c\u793c\u76d2\u88c5\u5e7f\u5f0f\u86cb\u9ec4\u83b2\u84c9\u8c46\u6c99\u51b0\u76ae\u6708\u997c\u6563\u88c5\u591a\u53e3\u5473\u4e2d\u79cb\u9001\u793c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6708\u997c\u5546\u54c1\u9500\u91cfTop10",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e5bcdacf90af4587bd2e07a480c25bde.setOption(option_e5bcdacf90af4587bd2e07a480c25bde);
#                 var chart_3be233316eb34ca097fbc9fd4f9d6f3a = echarts.init(
#                     document.getElementById('3be233316eb34ca097fbc9fd4f9d6f3a'), 'white', {renderer: 'canvas'});
#                 var option_3be233316eb34ca097fbc9fd4f9d6f3a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "sales_num",
#             "data": [
#                 914556.0,
#                 668112.0,
#                 487861.0,
#                 309570.0,
#                 306026.0,
#                 301724.0,
#                 185000.0,
#                 177142.0,
#                 101385.0,
#                 100000.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,

# %%
page.render()
# Out:
# 'C:\\Users\\黄伟\\Desktop\\publish\\常用模块\\re模块\\render.html'

# %%
Page.save_resize_html('render.html',cfg_file= 'chart_config.json')
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n    <meta charset="UTF-8">\n    <title>Awesome-pyecharts</title>\n            <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts-wordcloud.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/maps/china.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/jquery.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/jquery-ui.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/ResizeSensor.js"></script>\n\n            <link rel="stylesheet"  href="https://assets.pyecharts.org/assets/jquery-ui.css">\n\n</head>\n<body>\n    <style>.box {  }; </style>\n        \n    <div class="box">\n                <div id="e5bcdacf90af4587bd2e07a480c25bde" class="chart-container" style="position: absolute; width: 1360px; height: 394px; top: 845px; left: 2px;"></div>\n    <script>\n        var chart_e5bcdacf90af4587bd2e07a480c25bde = echarts.init(\n            document.getElementById(\'e5bcdacf90af4587bd2e07a480c25bde\'), \'white\', {renderer: \'canvas\'});\n        var option_e5bcdacf90af4587bd2e07a480c25bde = {\n    "animation": true,\n    "animationThreshold": 2000,\n    "animationDuration": 1000,\n    "animationEasing": "cubicOut",\n    "animationDelay": 0,\n    "animationDurationUpdate": 300,\n    "animationEasingUpdate": "cubicOut",\n    "animationDelayUpdate": 0,\n    "color": [\n        "#c23531",\n        "#2f4554",\n        "#61a0a8",\n        "#d48265",\n        "#749f83",\n        "#ca8622",\n        "#bda29a",\n        "#6e7074",\n        "#546570",\n        "#c4ccd3",\n        "#f05b72",\n        "#ef5b9c",\n        "#f47920",\n        "#905a3d",\n        "#fab27b",\n        "#2a5caa",\n        "#444693",\n        "#726930",\n        "#b2d235",\n        "#6d8346",\n        "#ac6767",\n        "#1d953f",\n        "#6950a1",\n        "#918597"\n    ],\n    "series": [\n        {\n            "type": "bar",\n            "name": "sales_num",\n            "data": [\n                800000.0,\n                650000.0,\n                450000.0,\n                300000.0,\n                300000.0,\n                200000.0,\n                150000.0,\n                100000.0,\n                100000.0,\n                100000.0\n            ],\n            "barCategoryGap": "20%",\n            "label": {\n                "show": true,\n                "position": "top",\n                "margin": 8\n            }\n        }\n    ],\n    "legend": [\n        {\n            "data": [\n                "sales_num"\n            ],\n            "selected": {\n                "sales_num": true\n            },\n            "show": true,\n            "padding": 5,\n            "itemGap": 10,\n            "itemWidth": 25,\n            "itemHeight": 14\n        }\n    ],\n    "tooltip": {\n        "show": true,\n        "trigger": "item",\n        "triggerOn": "mousemove|click",\n        "axisPointer": {\n            "type": "line"\n        },\n        "textStyle": {\n            "fontSize": 14\n        },\n        "borderWidth": 0\n    },\n    "xAxis": [\n        {\n            "show": true,\n            "scale": false,\n            "nameLocation": "end",\n            "nameGap": 15,\n            "gridIndex": 0,\n            "axisLabel": {\n                "show": true,\n                "position": "top",\n                "rotate": -15,\n                "margin": 8\n            },\n            "inverse": false,\n            "offset": 0,\n            "splitNumber": 5,\n            "minInterval": 0,\n            "splitLine": {\n                "show": false,\n                "lineStyle": {\n                    "width": 1,\n                    "opacity": 1,\n                    "curveness": 0,\n            ...

# %% [markdown]
# # 公众号

# %% [markdown]
# ![image.png](attachment:image.png)
